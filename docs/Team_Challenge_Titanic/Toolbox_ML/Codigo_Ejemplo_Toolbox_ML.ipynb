# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

from bootcampviztools import *
from scipy.stats import mannwhitneyu
from scipy.stats import pearsonr
from scipy.stats import shapiro
from scipy.stats import ttest_ind
from scipy import stats
from Toolbox_ML import *

# %% [markdown]
# ### Data

# %%
boston = pd.read_csv("./data/boston.csv", sep = "|")

iris = pd.read_csv("./data/iris.csv")

titanic = pd.read_csv("./data/titanic.csv")
titanic = titanic.dropna() # Eliminamos todas las filas que contienen nulos

# %% [markdown]
# ## Toolbox_ML

# %% [markdown]
# ### Función | describe_df

# %% [markdown]
# ### Función | tipifica_variables

# %%
tipifica_variables(titanic, umbral_categoria = 5, umbral_continua = 10)
# Out:
#    nombre_variable      tipo_sugerido
# 0         survived            Binaria
# 1           pclass         Categórica
# 2              sex            Binaria
# 3              age  Numérica Continua
# 4            sibsp         Categórica
# 5            parch         Categórica
# 6             fare  Numérica Continua
# 7         embarked         Categórica
# 8            class         Categórica
# 9              who         Categórica
# 10      adult_male            Binaria
# 11            deck  Numérica Discreta
# 12     embark_town         Categórica
# 13           alive            Binaria
# 14           alone            Binaria

# %% [markdown]
# ### Función | get_features_num_regression

# %% [markdown]
# ### Función | plot_features_num_regression

# %% [markdown]
# ### Función | get_features_cat_regression

# %% [markdown]
# ### Función | plot_features_cat_regression

# %%
plot_features_cat_regression(titanic, "fare", [], 0.05)
# Out:
# ['pclass', 'sibsp', 'parch', 'embarked', 'class', 'embark_town']
